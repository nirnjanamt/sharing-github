# %%
import numpy as np 
import pandas as pd 
import seaborn as sns

# %%
df=pd.read_csv('D:/covid data/COVID-19 India Statewise Vaccine Data.csv')

# %%
df.head(10)
# Out:
#                                   State/UTs    Dose 1   Dose 2  \
# 0                       Andaman and Nicobar    209744    91633
# 1                            Andhra Pradesh  16301408  5586517
# 2                         Arunachal Pradesh    672715   174809
# 3                                     Assam   8878074  1949091
# 4                                     Bihar  20782782  3919266
# 5                                Chandigarh    646847   197592
# 6                              Chhattisgarh   9652189  2357947
# 7  Dadra and Nagar Haveli and Daman and Diu    557768    74936
# 8                                     Delhi   7435141  2671573
# 9                                       Goa   1061081   274247
#
#    Total Vaccination Doses
# 0                   301377
# 1                 21887925
# 2                   847524
# 3                 10827165
# 4                 24702048
# 5                   844439
# 6                 12010136
# 7                   632704
# ...

# %%
df.describe()
# Out:
#              Dose 1        Dose 2  Total Vaccination Doses
# count  3.700000e+01  3.700000e+01             3.700000e+01
# mean   9.945800e+06  2.817001e+06             1.276280e+07
# std    1.083449e+07  3.040486e+06             1.371667e+07
# min    5.040500e+04  1.600100e+04             6.640600e+04
# 25%    6.727150e+05  1.975920e+05             8.475240e+05
# 50%    7.435141e+06  1.834865e+06             9.719028e+06
# 75%    1.630141e+07  4.241105e+06             2.188792e+07
# max    4.064759e+07  1.123179e+07             4.844314e+07

# %%
df1=df.sort_values(by="Total Vaccination Doses",ascending=False)
dfsort1=df1.iloc[0:8]
df1.head(7)
# Out:
#          State/UTs    Dose 1    Dose 2  Total Vaccination Doses
# 33   Uttar Pradesh  40647594   7795548                 48443142
# 20     Maharashtra  33440863  11231791                 44672654
# 10         Gujarat  25456493   8284150                 33740643
# 28       Rajasthan  25284389   7530701                 32815090
# 19  Madhya Pradesh  27053585   5175306                 32228891
# 15       Karnataka  24088034   6577674                 30665708
# 35     West Bengal  21103280   8704093                 29807373

# %%
sns.catplot(x="State/UTs", y="Total Vaccination Doses", kind="bar",data=dfsort1,aspect=2)

# %%
df2=df.sort_values(by="Total Vaccination Doses")
dfsort2=df2.iloc[0:8]
df2.head(7)
# Out:
#                                    State/UTs  Dose 1  Dose 2  \
# 18                               Lakshadweep   50405   16001
# 17                                    Ladakh  187397   67650
# 0                        Andaman and Nicobar  209744   91633
# 7   Dadra and Nagar Haveli and Daman and Diu  557768   74936
# 29                                    Sikkim  491204  148121
# 26                                Puducherry  574641  145668
# 24                                  Nagaland  617903  149873
#
#     Total Vaccination Doses
# 18                    66406
# 17                   255047
# 0                    301377
# 7                    632704
# 29                   639325
# 26                   720309
# 24                   767776
